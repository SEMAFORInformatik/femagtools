# %% [markdown]
# # Material Handling
#
# There are 3 groups of material in Femag: lamination, magnets and conductors.
#
# ## Lamination Material
#
# FEMAG uses binary formatted MC/MCV files for the properties of lamination material. This is how MCV files can be read:

# %%
import femagtools.mcv

# %%
mcvreader = femagtools.mcv.Reader()
mcvreader.readMcv('laminations/M270-35A.MC')

# %%
mcvreader.get_results()
# Out:
# {'name': 'M270-35A',
#  'desc': 'Magnetic Curve                          ',
#  'cversion': 0,
#  'ctype': 1,
#  'recalc': 0,
#  'remz': 0.0,
#  'bsat': 0.0,
#  'bref': 0.0,
#  'fillfac': 1.0,
#  'fo': 50.0,
#  'Bo': 1.5,
#  'ch': 0.0,
#  'ch_freq': 1.0,
#  'cw': 3.0,
#  'cw_freq': 1.4500000476837158,
#  'b_coeff': 1.850000023841858,
#  'rho': 7.650000095367432,
#  'fe_sat_mag': 2.1500000953674316,
#  'curve': [{'hi': [0.0,
#     10.0,
#     20.0,
#     30.0,
#     40.0,
#     50.0,
#     60.0,
#     70.0,
#     80.0,
#     90.0,
#     100.0,
#     200.0,
#     300.0,
#     400.0,
#     500.0,
#     600.0,
#     700.0,
#     800.0,
#     900.0,
#     1000.0,
#     2000.0,
#     3000.0,
#     4000.0,
#     5000.0,
#     6000.0,
#     7000.0,
#     8000.0,
#     9000.0,
#     10000.0,
#     20000.0,
#     30000.0,
#     40000.0,
#     50000.0,
#     60000.0,
#     70000.0,
#     80000.0,
#     90000.0,
#     100000.0,
#     200000.0,
#     500000.0],
#    'bi': [0.0,
#     0.10174000263214111,
#     0.2011370062828064,
#     0.29615598917007446,
#     0.38528698682785034,
#     0.4676159918308258,
#     0.5427759885787964,
#     0.6108270287513733,
#     0.6721190214157104,
#     0.7271659970283508,
#     0.7765570282936096,
#     1.0706720352172852,
#     1.19780695438385,
#     1.2671619653701782,
#     1.3110430240631104,
#     1.3416420221328735,
#     1.3644800186157227,
#     1.382403016090393,
#     1.3970229625701904,
#     1.4093159437179565,
#     1.4805519580841064,
#     1.5231300592422485,
#     1.558081030845642,
#     1.589516043663025,
#     1.6187200546264648,
#     1.646183967590332,
#     1.672116994857788,
#     1.6966110467910767,
#     1.7197109460830688,
#     1.8815209865570068,
#     1.9547009468078613,
#     1.9886070489883423,
#     2.0083839893341064,
#     2.023422956466675,
#     2.0368940830230713,
#     2.049838066101074,
#     2.062593936920166,
#     2.0752789974212646,
#     2.2013800144195557,
#     2.5786280632019043],
#    'angle': 0.0}]}

# %% [markdown]
# Display the B(H) curve in a linear plot:

# %%
import matplotlib.pyplot as plt

plt.plot(mcvreader['curve'][0]['hi'], mcvreader['curve'][0]['bi'])
plt.grid()

# %% [markdown]
# or with the plot module:

# %%
import femagtools.plot
femagtools.plot.mcv_hbj(mcvreader, log=True)
plt.show()

# %% [markdown]
# Display the relative permeability:

# %%
femagtools.plot.mcv_muer(mcvreader)
plt.show()

# %% [markdown]
# A new BH curve can be created from a dict:

# %%
mcvData = dict(curve=[ dict(
     bi=[0.0, 0.09, 0.179, 0.267, 0.358,
         0.45, 0.543, 0.6334, 0.727,
         0.819, 0.9142, 1.0142, 1.102,
         1.196, 1.314, 1.3845, 1.433,
         1.576, 1.677, 1.745, 1.787,
         1.81, 1.825, 1.836],
 
     hi=[0.0, 22.16, 31.07, 37.25, 43.174,
          49.54, 56.96, 66.11, 78.291,
          95, 120.64, 164.6, 259.36,
          565.86, 1650.26, 3631.12, 5000, 10000,
          15000, 20000, 25000, 30000, 35000, 40000]
      )],
      ctype=femagtools.mcv.MAGCRV,
      name='m270-35a',
      desc=u"Demo Steel",
      ch=0.0,
      cw_freq=2.0,
      cw=1.68)

# %% [markdown]
# The MCV dict must contain a list of curves. If the material is soft iron this list has exactly one dict with the 2 lists of bi and hi.

# %%
fig, axs = plt.subplots(ncols=2, figsize=(8,4))
femagtools.plot.mcv_hbj(mcvData, log=False, ax=axs[0])
femagtools.plot.mcv_hbj(mcvData, log=True, ax=axs[1])

# %%
mcv = femagtools.mcv.MagnetizingCurve(mcvData)
mcv.writefile('m270-35a')
# Out:
# 'm270-35a.MCV'

# %%
mcvreader.readMcv('m270-35a.MCV')

# %%
mcvreader['curve'][0]['bi']
# Out:
# [0.0,
#  0.09000000357627869,
#  0.17900000512599945,
#  0.2669999897480011,
#  0.3580000102519989,
#  0.44999998807907104,
#  0.5429999828338623,
#  0.633400022983551,
#  0.7269999980926514,
#  0.8190000057220459,
#  0.9142000079154968,
#  1.01419997215271,
#  1.1019999980926514,
#  1.1959999799728394,
#  1.3140000104904175,
#  1.3845000267028809,
#  1.4329999685287476,
#  1.5759999752044678,
#  1.6770000457763672,
#  1.7450000047683716,
#  1.7869999408721924,
#  1.809999942779541,
#  1.8250000476837158,
#  1.8359999656677246]

# %% [markdown]
# Magnetic curve dicts can also be created from TKS files:

# %%
import femagtools.tks
import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s %(message)s')
tks = femagtools.tks.read('laminations/TKS-M400-65A.txt')
femagtools.plot.mcv_hbj(tks, log=False)
plt.show()
# Out:
# 2023-10-24 10:39:45,221 laminations/TKS-M400-65A.txt Bmax 1.91
# 2023-10-24 10:39:45,224 Jordan loss coeffs [0.60184032 0.01816424 2.70400836 1.72807171 2.23143371]
# 2023-10-24 10:39:45,226 Steinmetz loss coeffs [2.94909102 1.68846104 2.22983366]

# %% [markdown]
# If the TKS file includes losses they are fitted with the Jordan approximation:

# %%
ch = tks['ch']
alpha = tks['ch_freq']
cw = tks['cw']
beta = tks['cw_freq']
gamma = tks['b_coeff']

femagtools.plot.felosses(tks['losses'], (ch, alpha, cw, beta, gamma), log=False)
plt.show()

# %%
tks['losses']
# Out:
# {'f': [50.0, 100.0, 200.0, 400.0],
#  'B': [0.6,
#   0.7,
#   0.7999999999999999,
#   0.8999999999999999,
#   0.9999999999999999,
#   1.0999999999999999,
#   1.1999999999999997,
#   1.2999999999999998,
#   1.4,
#   1.4999999999999998,
#   1.5999999999999996,
#   1.6999999999999997,
#   1.7999999999999998],
#  'cw': 2.949091017207515,
#  'cw_freq': 1.6884610418555146,
#  'b_coeff': 2.229833664616225,
#  'Bo': 1.5,
#  'fo': 50.0,
#  'pfe': [[0.6184846623678998,
#    0.7820909036227961,
#    1.005609456949922,
#    1.2364446193672063,
#    1.4863831645663632,
#    1.7645234720540768,
#    2.088224179444146,
#    2.4521188646457315,
#    2.9017655916709155,
#    3.434009600093662,
#    3.903522218495639,
#    4.252320254313521,
#    4.6656123143839965],
#   [1.6055181246032564,
#    2.1465368942456373,
#    2.749742857774846,
#    3.380237407764824,
#    4.115223454452131,
#    4.926505300885987,
#    5.88102783310848,
#    6.919001346026851,
#    8.146626903481913,
#    9.704304197440532,
#    11.070882741021764,
#    12.24685805441727,
#    None],
#   [4.524686370787231,
#    6.037123319782786,
#    7.8319821381362384,
#    9.963889379467572,
#    12.380345243047255,
#    15.026576450040523,
#    18.078292507227232,
#    21.552603013935002,
#    25.88910212278471,
#    30.51439345142431,
#    None,
#    None,
#    None],
#   [13.127911203442338,
#    17.922055874082563,
#    23.798691716469705,
#    30.841297209405354,
#    39.34346229879803,
#    48.97389844259971,
#    60.25629980957752,
#    72.88007908653783,
#    None,
#    None,
#    None,
#    None,
#    None]]}

# %% [markdown]
# ## Magnet Material
#
# Magnets can be defined by magnetizing curve or in the linear case which is used convienently by the remanence and the relative permeability:

# %%
magnets = [dict(name='MX-333', remanenc=1.2, relperm=1.05)]

# %% [markdown]
# Additional keys are spmaweight, temcoefbr, temcoefhc, magncond, thcond, thcap:

# %%
magnets = [
    {"name": "N42UH",
    "remanenc": 1.31,
    "relperm": 1.05,
    "spmaweight": 7.6,
    "temcoefbr": -0.001575,
    "temcoefhc": -0.007,
    "magncond": 1/1.5e-6,
    "thcond": 6.164,
    "thcap": 460}]

# %% [markdown]
# For nonlinear magnet material a magnetizing curve can be used:

# %%
magnets=[dict(name='BH53M', mcvkey='BH53M',
                     orient='mcartiso', rlen=1.0)]

# %% [markdown]
# The mcvkey can either reference a file or an entry in the magnetizing curve dict.

# %% [markdown]
# The magnet material is attached to the model using the key "material":

# %% [markdown]
# ```
# machine = { ..
#
#    'magnet': {
#        'material': 'N42UH'
#        ...
# ```

# %% [markdown]
# ## Conductor Material

# %% [markdown]
# Conductor properties are collected in a list of dict values:

# %%
condMat = [
    {'name': 'Cu',
     "spmaweight": 8.96,
     "elconduct": 56e6,
     "tempcoef": 3.9e-3,
     "thcond": 30,
     "thcap": 480 }]

# %% [markdown]
# The conductor material is attached to the model using the key "material"

# %% [markdown]
# ```
# machine = { ..
#
#   'winding': {
#       'material': 'Cu'
#       ..
# ```
